# %% [markdown]
# ### Task 1: Variable Declaration and Data Types

# %% [markdown]
# ### Declaring Variables

# %%
type (34)
# Out:
# int

# %%
type (3.4)
# Out:
# float

# %%
name = "Isabel"
type (name)
# Out:
# str

# %%
is_student_active = True
type (is_student_active)
# Out:
# bool

# %% [markdown]
# ### Data Types

# %%
age = 34
print (age)
# Out:
# 34

# %%
type (age)
# Out:
# int

# %%
height = 160 
print (height)
# Out:
# 160

# %%
type (height)
# Out:
# int

# %%
name = "Isabel"
print (name)
# Out:
# Isabel

# %%
type (name)
# Out:
# str

# %%
is_student_active = True
print (is_student_active)
# Out:
# True

# %% [markdown]
# ### Task 2: String Manipulation

# %%
res1= "Hello" +" Isabel"

# %%
print (res1)
# Out:
# Hello Isabel

# %%
type (res1)
# Out:
# str

# %%
print(res1.upper())
# Out:
# HELLO ISABEL

# %%
print(res1.capitalize())
# Out:
# Hello isabel

# %%
print(res1.replace("Hello", "Goodbye"))
# Out:
# Goodbye Isabel

# %% [markdown]
# ### Task 3: Basic Operations

# %% [markdown]
# #### Arithmetic operations

# %%
a = 20
b = 40
print(a + b)
# Out:
# 60

# %%
print(a - b)
# Out:
# -20

# %%
print(a * b)
# Out:
# 800

# %%
print(a / b)
# Out:
# 0.5

# %%
print(a % b)
# Out:
# 20

# %%
print(a ** b)
# Out:
# 10995116277760000000000000000000000000000000000000000

# %% [markdown]
# #### Comparison Operations

# %%
a = 15
b = 20

# %%
print (a == b)
# Out:
# False

# %%
a = b

# %%
print (a)
# Out:
# 20

# %%
print (a != b)
# Out:
# False

# %%
print (a >= 15)
# Out:
# True

# %%
print (a > 15)
# Out:
# True

# %%
print (a < 15)
# Out:
# False

# %% [markdown]
# #### Logical Operators

# %%
is_rainning = True
is_cold = False

# %%
print (is_rainning and is_cold)
# Out:
# False

# %%
print (is_rainning or is_cold)
# Out:
# True

# %% [markdown]
# ### Task 4: Data Collections

# %% [markdown]
# #### List

# %%
colors = ["pink", "blue", "yellow"]

# %%
print("List elements:", colors[2])
# Out:
# List elements: yellow

# %% [markdown]
# #### Dictionary

# %%
student = { "name": "Isabel" , "major": "supply chain" , "age": "34" }

# %%
print("Dictionary value:", student["major"])
# Out:
# Dictionary value: supply chain

# %% [markdown]
# #### Tuple

# %%
coordinates = (50, 60)

# %%
print("Tuple element:", coordinates[1])
# Out:
# Tuple element: 60

# %% [markdown]
# ### Task 5: Expression Combination

# %%
print("Task 5: Combined Expression")
# Out:
# Task 5: Combined Expression

# %%
age = 25
height = 5.3
a = 5
b= 2

# %%
total_score = (a * b) + (age / 5) - (height ** 2)

# %%
print("Result:", total_score)
# Out:
# Result: 376.91
